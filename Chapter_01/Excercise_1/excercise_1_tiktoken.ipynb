# %%
# %pip install --upgrade tiktoken
# %pip install --upgrade openai
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.2 MB/s  0:00:00
# ...
#   Attempting uninstall: jiter
#     Found existing installation: jiter 0.8.0
#     Uninstalling jiter-0.8.0:
#       Successfully uninstalled jiter-0.8.0
#   Attempting uninstall: openai
#     Found existing installation: openai 1.56.0
#     Uninstalling openai-1.56.0:
#       Successfully uninstalled openai-1.56.090m━━━━━━━━━━━━━━━━━━━ 1/2 [openai]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openai]2m1/2 [openai]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import tiktoken
encoding = tiktoken.get_encoding("o200k_base")
encoding = tiktoken.encoding_for_model("gpt-5")
encoding.encode("Running is an Olympic sporting event")
# Out:
# [28738, 382, 448, 42083, 48755, 2104]

# %%
def compare_encodings(example_string: str) -> None:
    """Prints a comparison of three string encodings."""
    # print the example string
    print(f'\nExample string: "{example_string}"')
    # for each encoding, print the # of tokens, the token integers, and the token bytes
    for encoding_name in ["r50k_base", "p50k_base", "cl100k_base", "o200k_base"]:
        encoding = tiktoken.get_encoding(encoding_name)
        token_integers = encoding.encode(example_string)
        num_tokens = len(token_integers)
        token_bytes = [encoding.decode_single_token_bytes(token) for token in token_integers]
        print()
        print(f"{encoding_name}: {num_tokens} tokens")
        print(f"token integers: {token_integers}")
        print(f"token bytes: {token_bytes}")

# %%
compare_encodings("I woke up early this morning and made a fresh cup of coffee. 外面的天气很冷，但阳光明媚，让人感觉很舒服。After breakfast, I reviewed my notes for the meeting. 我的老板今天看起来心情很好，我们的讨论也很顺利。Now I just need to finish the report before the end of the day.")
# Out:
# Example string: "I woke up early this morning and made a fresh cup of coffee. 外面的天气很冷，但阳光明媚，让人感觉很舒服。After breakfast, I reviewed my notes for the meeting. 我的老板今天看起来心情很好，我们的讨论也很顺利。Now I just need to finish the report before the end of the day."
#
# r50k_base: 135 tokens
# ...
